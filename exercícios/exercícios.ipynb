# %% [markdown]
# <a href="https://colab.research.google.com/github/NycolasFreitasL/logicaprogramacaopython/blob/main/exerc%C3%ADcios/exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##quadrado dos numeros
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %%
n1 = int(input("digite o seu primeiro numero "))
n2 = int(input("digite seu segundo numero "))
n3 = int(input("digite seu terceiro numero "))
n4 = int(input("digite seu quarto numero "))
nn1 = n1**2
nn2 = n2**2
nn3 = n3**2
nn4 = n4**2
print("o quadrdo do seus numeros são: ",nn1,nn2,nn3,nn4)
res = nn1+nn2+nn3+nn4
print("a soma deles é: ",res)

# %% [markdown]
# ##dolar
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
dolar = float(input("Qual a cotação do dolar atual? R$"))
dinheiro = float(input("Quando deseja tranferir? R$"))
cotacao = dinheiro/dolar
print("voce tem $",cotacao )

# %% [markdown]
# ## comissão
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
carro = 100
produto2 = 0
p2qtde = 0
moto = 50
bicicleta = 20
comissao = int(input("qual a sua comissão? "))
produto = str(input("qual produto voce vendeu? "))
if produto == "carro": produto=100; pqtde = int(input("quantos exemplares voce vendeu? "))
elif produto == "moto": produto=50; pqtde = int(input("quantos exemplares voce vendeu? "))
elif produto == "bicicleta":produto=20; pqtde = int(input("quantos exemplares voce vendeu? "))
else : "não temos esse produto"
vendas = produto * pqtde
pergunta = str(input("vendeu algun outro produto?"))
res = (vendas*comissao)/100
if pergunta == "sim": produto2 = str(input("qual produto voce vendeu? "))
else : print("você tem: ",vendas,"R$ de vendas e: ",res,"R$ de comissao, total: ",vendas + res,"R$")
if produto2 == "carro": produto2=100; p2qtde = int(input("quantos exemplares voce vendeu? "))
elif produto2 == "moto": produto2=50; p2qtde = int(input("quantos exemplares voce vendeu? "))
elif produto2 == "biciclita": produto2=20; p2qtde = int(input("quantos exemplares voce vendeu? "))
else : print("obrigado por nos usar")
vendas2 = produto2 * p2qtde
somavendas = vendas + vendas2
res2 = (somavendas*comissao)/100
if produto2 : print("voce vendeu: ",somavendas,"R$ e sua comissão é: ",res,"R$ com o total de: ",res2+somavendas,"R$")
else: "codigo encerrado"

# %%
valor = int(input("qual o valor do produto? "))
qtde = int(input("quantos exemplares faram vendidos? "))
venda = valor * qtde
comissao = (venda*5)/100
total = venda + comissao
valor = int(input("qual o valor do produto? "))
qtde = int(input("quantos exemplares faram vendidos? "))
venda = valor * qtde
comissao = (venda*5)/100
total = venda + comissao
print("voce vendeu: ",venda,"R$ de produto, e sua comissão é de: ",comissao,"R$ sendo o valor total de vendas: ",total,"R$")
print("voce vendeu: ",venda,"R$ de produto, e sua comissão é de: ",comissao,"R$ sendo o valor total de vendas: ",total,"R$")

# %% [markdown]
# ## gasolina
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %%
distancia = float(input("qual a distancia a percorrer "))
consumo = float(input("qual o consumo médio por kilometro do seu carro "))
gasolina = float(input("qual o preço médio da gasolina? "))
litros = distancia/consumo
custo = litros * gasolina
print("você precisará de ",custo,"R$")

# %% [markdown]
# ## hora
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %%
hora=float(input("selecione as horas"))
minutos=float(input("selecione os minuto"))
minutot=minutos/60
horat=hora+minutot
print("seu numero é: ",horat)

# %% [markdown]
# ## hora extra
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
ganhos = float(input("selecione os ganhos por hora"))
hora=float(input("selecione as horas trabalhadas"))
minutos=float(input("selecione os minuto trabalhados"))
minutot=minutos/60
horat=hora+minutot
sal = horat * ganhos
total = sal*0.70+sal
print("seu salario vai ser ",total)

# %% [markdown]
# ## media notas
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
p1 = float(input("digite a nota da primeira prova"))
p2 = float(input("digite a nota da segunda prova"))
m = (p1+p2)/2
print("sua média é: ", m)

# %% [markdown]
# ## preço do carro
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
fabrica=float(input("qual o valor de fabrica do veículo?"))
imposto= fabrica * 0.45 + fabrica
distribuidor = imposto * 0.28 + imposto
print("o preço do veículo é: ",distribuidor)

# %% [markdown]
# ## quantidade e valor
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
valor = float(input("digite o valor do produto"))
QTDE = int(input("digite a quantidade do produto"))
VT = valor*QTDE
print("O valor da sua compra é: ", VT)

# %% [markdown]
# ## sistema de multas
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
distancia = float(input("qual a distancia percorrida? "))
tempo = float(input("qual o tempo que foi levado pra concluir a distancia? "))
multa = 250.50
vm= distancia/tempo
if vm > 60 : print("sua velocidade média foi ",vm,"você levou uma multa de ",multa,"R$" )
else :print( "sua velocidade média foi de estava dentro dos limites de velocidade, continue assim :)")
